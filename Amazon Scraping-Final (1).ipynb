# %%
import pandas as pd
from bs4 import BeautifulSoup 
from selenium import webdriver
import lxml
import lxml.html.soupparser
import re
import requests
import json
import random

# %%
# identifying the variables
products = []
headers = {
        'accept-encoding': 'gzip, deflate, sdch, br',
        'accept-language': 'en-US,en;q=0.8,zh-CN;q=0.6,zh;q=0.4',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'cache-control': 'max-age=0',
    }
base_url = "https://www.amazon.com/s?k="

# %%
# function to gather the links to the products' pages
def linkc(item):
    # put together the url to scrape from
    url = base_url + item
    # uncomment to watch the progress
    #print('begin scraping the data', url)
    
    # get the page data
    request = requests.get(url, headers=headers)
    soup = BeautifulSoup(request.text, 'lxml')
    body = soup.find('body')
    main_outlet = body.find('div',{'class':"s-main-slot s-result-list s-search-results sg-row"})
    links = main_outlet.find_all('a',{'class':'a-link-normal a-text-normal'})
    # get the links to pages
    for i in links:
        products.append('https://www.amazon.com' + i.get('href'))

# %%
# lists to store the data
prices = []
review_nums = []
review_scores = []
stock = []
titles = []
imgs = []
k = 1
def pagec(products,prices,review_nums,review_scores,stock,titles,imgs,k):
    # begin scraping
    for page in products:
        # uncomment to watch the progress
        #print('begin scrapping the product page: ', page)
        #print('page number',k,'--- left:',len(products)-k)
        
        k = k + 1

        # get the page
        request = requests.get(page, headers=headers)
        soup1 = BeautifulSoup(request.text, 'lxml')

        # get the title of the item
        titles.append(soup1.find(id='productTitle').get_text().strip())

        # get the price
        try:
            prices.append(float(soup1.find('span',{'id':re.compile('^priceblock_')}).get_text().replace('$', '').replace(',', '.').strip()))
        except:
            try:
                prices.append(float(soup1.find('span',{'class':re.compile('^price')}).get_text().replace('$', '').replace(',', '.').strip()))
            except:
                prices.append('')

        # review score
        review_scores.append(float(soup1.find('span',{'class':'a-icon-alt'}).get_text().strip()[:3]))

        # how many reviews
        review_nums.append(int(soup1.select('#acrCustomerReviewText')[0].get_text().split(' ')[0].replace(".", "").replace(",","")))

        # whether it is available
        try:
            soup1.select('#availability .a-color-state')[0].get_text().strip()
            stock.append('Out of Stock')
        except:
            stock.append('Available')

         # get the link to the source image
        try:
            imgs.append(soup1.find('img',{'alt':titles[-1]}).get('data-old-hires').strip())
        except:
            imgs.append('')

# %%
# get the input
item = input()
# lowercase the input and format it
item = item.lower().strip().replace(' ','+')

# run the functions
linkc(item)
pagec(products,prices,review_nums,review_scores,stock,titles,imgs,k)

# json output
jj = json.dumps({'title':titles,'price':prices,'availability':stock,'score':review_scores,'number of reviews':review_nums,'image':imgs},indent=4)
print(jj)
# Out:
# men sunglasses
# {
#     "title": [
#         "Polarized Sunglasses Classic Men Women Retro Brand Designer Sun Glasses\uff08No Slip, No Bounce, All Polarized\uff09",
#         "Sports Polarized Sunglasses For Men Cycling Driving Fishing 100% UV Protection",
#         "ATTCL Men's Retro Metal Frame Driving Polarized Sunglasses For Men",
#         "SUNGAIT Ultra Lightweight Rectangular Polarized Sunglasses UV400 Protection",
#         "Polarized Sunglasses for Men Retro - FEIDU Polarized Retro Sunglasses for Men FD2149",
#         "Aviator Sunglasses for Men Polarized Women -MXNX UV Protection Lightweight Driving Fishing Sports Mens Sunglasses MX208",
#         "MERRY'S Unisex Polarized Aluminum Sunglasses Vintage Sun Glasses For Men/Women S8286",
#         "Ray-Ban Rb3016 Clubmaster Square Sunglasses",
#         "SUNGAIT Ultra Lightweight Rectangular Polarized Sunglasses UV400 Protection",
#         "Joopin Semi Rimless Polarized Sunglasses Women Men Retro Brand Sun Glasses",
#         "SOJOS Polarized Sunglasses for Men Women Retro Aviator Square Goggle Classic Alloy Frame HERO SJ1126",
#         "Ray-Ban Rb3025 Aviator Classic Sunglasses",
#         "Oakley Men's Oo9096 Fuel Cell Rectangular Sunglasses",
#         "Ray-Ban RB4171 Erika Sunglasses",
#         "Oakley Men's Oo9236 Valve Rectangular Sunglasses",
#         "Giovent\u00f9 Polarized Sunglasses - UV400 Protection NXT Trivex Advanced Lenses, Classic Unisex Wayfarer Sunglasses for Men and Women, Outdoors Sport Driving Fishing Cycling Hiking",
#         "Carrera Men's Ca1004/S Pilot Sunglasses",
#         "Ray-Ban Rb3447 Round Metal Sunglasses",
#         "FAGUMA Polarized Sports Sunglasses For Men Cycling Driving Fishing 100% UV Protection",
#         "Ray-Ban Rb4125 Cats 5000 Aviator Sunglasses",
#         "Ray-Ban RB3025 Aviator Classic Polarized Sunglasses",
#         "NIEEPA Men's Sports Polarized Sunglasses Square Frame Glasses",
#         "ATTCL Polarized UV Protection Sports Fishing Driving Sunglasses for Men Al-Mg Metal Frame Ultra Light Green",
#         "SOJOS Classic Round Retro Plastic Frame Vintage Large Sunglasses BLOSSOM SJ2067",
#         "Carrera Ca5039/S Rectangular Sunglasses",
#         "Under Armour Men's Ranger Rectangular Sunglasses",
#         "Oakley mens Oo9239 Crankshaft Rectangular Sunglasses Rectangular Sunglasses",
#         "DUCO Men's Luxury Carbon Fiber Temple Polarized Sunglasses for Men Sports UV400 DC8206",
#         "ATTCL Sports Polarized Sunglasses For Men Cycling Driving Fishing 100% UV Protection",
#         "Joopin Polarized Lennon Round Sunglasses Women Men Circle Hippie Sun Glasses",
#         "DUBERY Sport Polarized Sunglasses for Men UV Protection Driving Fishing Sun Glasses D620"
#     ],
#     "price": [
#         15.99,
#         19.97,
#         25.0,
#         15.99,
#         11.98,
#         15.55,
#         12.91,
#         154.0,
#         14.99,
#         114.95,
#         11.98,
#         16.99,
#         19.86,
#         22.99,
#         23.99,
#         21.98,
#         15.99,
#         12.99,
#         50.61,
#         21.99,
#         11.84,
#         19.98,
#         10.99,
#         18.99,
#         17.99,
#         34.99,
#         16.97,
#         26.0,
#         89.99,
#         16.98,
#         13.99,
#         15.99,
#         143.0,
#         15.99,
#         16.99,
#         189.0,
#         93.95,
#         178.0,
#         35.99,
#         26.99,
#         20.0,
#         24.0,
#         18.99,
#         26.99,
#         156.0,
#         132.0,
#         154.0,
#         10.99,
#         14.92,
#         154.0,
#         116.0,
#         147.0,
#         118.95,
#         19.99,
#         73.19,
#         154.0,
#         16.97,
#         165.0,
#         204.0,
#         10.99,
#         25.0,
#         13.85,
#         90.23,
#         56.99,
#         "",
#         35.0,
#         22.0,
#         9.99,
#         18.99
#     ],
#     "availability": [
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available",
#         "Available"
#     ],
#     "score": [
#         4.7,
#         4.5,
#         4.4,
#         4.6,
#         4.4,
#         4.4,
#         4.5,
#         4.7,
#         4.6,
#         4.6,
#         4.4,
#         4.0,
#         4.5,
#         4.2,
#         4.3,
#         4.0,
#         4.6,
#         4.3,
#         4.5,
#         4.4,
#         4.4,
#         4.4,
#         4.4,
#         4.6,
#         4.2,
#         4.3,
#         4.5,
#         4.4,
#         4.6,
#         4.5,
#         4.4,
#         4.4,
#         4.4,
#         4.3,
#         4.2,
#         4.6,
#         4.6,
#         4.4,
#         4.4,
#         4.6,
#         4.7,
#         4.1,
#         4.1,
#         4.5,
#         4.6,
#         4.5,
#         4.7,
#         4.4,
#         4.5,
#         4.6,
#         4.7,
#         4.6,
#         4.6,
#         5.0,
#         4.6,
#         4.4,
#         4.5,
#         4.4,
#         4.4,
#         4.1,
#         4.6,
#         4.6,
#         4.4,
#         4.5,
#         4.5,
#         4.4,
#         4.8,
#         4.4,
#         4.2
#     ],
#     "number of reviews": [
#         16,
#         3025,
#         3128,
#         12430,
#         3034,
#         1716,
#         13455,
#         838,
#         12430,
#         1689,
#         3034,
#         144,
#         63,
#         38,
#         57,
#         1,
#         12430,
#         1574,
#         455,
#         4417,
#         4746,
#         6551,
#         3450,
#         768,
#         630,
#         9,
#         531,
#         1163,
#         9,
#         1517,
#         5024,
#         1277,
#         6604,
#         1996,
#         760,
#         1603,
#         1463,
#         317,
#         437,
#         1587,
#         5,
#         427,
#         146,
#         3635,
#         212,
#         2827,
#         838,
#         7675,
#         1184,
#         3445,
#         682,
#         985,
#         295,
#         3,
#         239,
#         2015,
#         531,
#         251,
#         2505,
#         525,
#         172,
#         3679,
#         582,
#         176,
#         1350,
#         1677,
#         13,
#         4529,
#         162
#     ],
#     "image": [
#         "https://images-na.ssl-images-amazon.com/images/I/61tPFHPpvGL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71cIY9yTMCL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71mn3Iv6faL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61PmcMlhksL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61zL8epmQtL._AC_UL1100_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71gg1g1eavL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61ZhLl-4JPL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51gNzJh1R7L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61cFrWOdVJL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51OVLZ4i4pL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61zL8epmQtL._AC_UL1100_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61KXndAy2yL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51QjJSM%2Bv%2BL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51DLGKb0QoL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/5156bjK1rCL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51oO2w3C4yL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61PmcMlhksL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/717JOE0ks7L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61E%2B%2BPOnplL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61C9TISRAkL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61TAxeTjpxL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61ZPpGf-T0L._AC_UL1300_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/519NQwNO96L._AC_UL1260_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51wvSlIFN6L._AC_UL1000_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51V52ada7yL._AC_UL1000_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71%2B47uRTdeL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61JkYlv16tL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/710xa7HzU3L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71kExprdBfL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/515uTcXkl9L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71HsoeZrB6L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61IE1lmLytL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61zPHDvg8cL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/611agZoUpHL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51xS1ryescL._AC_UL1300_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51UI92Ec6kL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51-6rkophUL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/510TaWIuRUL._AC_UL1000_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/513tG4Pbb9L._AC_UL1000_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61Jvy4zXVSL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71G1fgatgwL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61l2HOUUlCL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51uPq8ruEoL._AC_UL1300_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61I6lWiyf5L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61rrdmTMiLL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51OMYrvUZRL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51gNzJh1R7L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61zYQGbKDsL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61Pn-BwBboL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51iC3FqSZGL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51i6B7CUUpL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51K%2B5%2BRkWAL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/412BW3CMTkL._AC_UL1024_.jpg",
#         "",
#         "https://images-na.ssl-images-amazon.com/images/I/61I6rm6Nv6L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51sd4Vw8EYL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61JkYlv16tL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71lNJsu4FQL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/5116xzc55yL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51oHa7-akIL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71j8OGhol6L._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61tTcVyQIeL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71eqQpTJUIL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/714BKKhzhFL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/51aVRea96dL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/71WmGwywafL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/81p3IdMsvpL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61dm8IHKOQL._AC_UL1500_.jpg",
#         "https://images-na.ssl-images-amazon.com/images/I/61XRsdpyZEL._AC_UL1500_.jpg"
#     ]
# }
